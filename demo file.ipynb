# %%
# %%writefile test_module.py#magic command
# def greet(name):
#     print(f'hello,{name}')
# def square(x):
#     return x**2
# #module is necessary to do multiple work simultaneously
# #magic command is not necessary when all the files will be in same folder
# Out:
# Writing test_module.py
