# %%
import test_module
test_module.greet('Arman')
test_module.square(10)
#first of all we have to import the demo file where we have already written the calculation
#then we can use function name to run the program
# Out:
# hello,Arman
# 100

# %%
from test_module import greet
greet('Arman')
#we can use specific part of a file
# Out:
# hello,Arman

# %%
from test_module import greet,square 
greet('Arman')
square(5)
#we can call multi0ple function simultaneously
# Out:
# hello,Arman
# 25
